# %%
#importing the module cv2 and numpy
import cv2
import numpy as np
import skimage
import matplotlib.pyplot as plt

# %%
#reading the image which is to be converted to HSV color space
loc='/home/karan/Remote-vegetation-sensing/project/data/sample.tiff'
imagergb = cv2.imread(loc)
hsvImage = cv2.cvtColor(imagergb, cv2.COLOR_BGR2HSV)

# %%
#converting the image to HSV color space using cvtColor function
imagehsv = cv2.cvtColor(imagergb, cv2.COLOR_BGR2HSV)
cv2.imwrite("/home/karan/Remote-vegetation-sensing/project/module/sample.tiff", imagergb)
cv2.imwrite("/home/karan/Remote-vegetation-sensing/project/module/sample_hsv.tiff", imagehsv)
# Out:
# True

# %%
def imagemask(lower,upper,name):
    lower=np.array(lower)
    upper=np.array(upper)
    imagemask=cv2.inRange(imagehsv, lower, upper)
    cv2.imwrite(f"/home/karan/Remote-vegetation-sensing/project/module/{name}.tiff", imagemask)

# %%
# imagemask fucntion Syntax imagemask([lowerthreshold],[upperthreshold],nameoffile)
imagemask([60, 42, 43],[135, 255, 255],"crop")
imagemask([29, 72, 39],[42, 100, 250],"barenland")
imagemask([0, 0, 0],[359, 84, 80],"cultivated_land")
imagemask([0, 87, 69],[130, 100, 80],"tree")

# %%
original='/home/karan/Remote-vegetation-sensing/project/module/sample.tiff'
hsv="/home/karan/Remote-vegetation-sensing/project/module/sample_hsv.tiff"
tree="/home/karan/Remote-vegetation-sensing/project/module/tree.tiff"
barenland="/home/karan/Remote-vegetation-sensing/project//module/barenland.tiff"
cultivated_land="/home/karan/Remote-vegetation-sensing/project/module/cultivated_land.tiff"
crop="/home/karan/Remote-vegetation-sensing/project/module/crop.tiff"

# %%
plt.imshow(imagergb)
plt.show()

# %%
plt.hist(imagergb.ravel(),256,[0,256])
plt.show()

# %%
hsv=cv2.imread(hsv)
plt.imshow(hsv)
plt.show()

# %%
  
# reading the image data from desired directory
img = cv2.imread(tree)
  
# counting the number of pixels
number_of_white_pix = np.sum(img == 255)
number_of_black_pix = np.sum(img == 0)
total=number_of_white_pix + number_of_black_pix
percent=(number_of_white_pix/total)*100
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)
print('Number of total pixels:', total)
print('Pecentage covered:', percent)
# Out:
# Number of white pixels: 3732
# Number of black pixels: 536268
# Number of total pixels: 540000
# Pecentage covered: 0.6911111111111111

# %%
# reading the image data from desired directory
img = cv2.imread(barenland)
  
# counting the number of pixels
number_of_white_pix = np.sum(img == 255)
number_of_black_pix = np.sum(img == 0)
total=number_of_white_pix + number_of_black_pix
percent=(number_of_white_pix/total)*100
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)
print('Number of total pixels:', total)
print('Pecentage covered:', percent)
# Out:
# Number of white pixels: 25389
# Number of black pixels: 514611
# Number of total pixels: 540000
# Pecentage covered: 4.701666666666666

# %%
image = cv2.imread(loc, cv2.IMREAD_GRAYSCALE)
thresh = cv2.threshold(image,0,255,cv2.THRESH_OTSU + cv2.THRESH_BINARY)[1]
pixels = cv2.countNonZero(thresh)
# pixels = len(np.column_stack(np.where(thresh > 0)))

image_area = image.shape[0] * image.shape[1]
area_ratio = (pixels / image_area) * 100

print('pixels', pixels)
print('area ratio', area_ratio)
# Out:
# pixels 26029
# area ratio 14.460555555555555

# %%
image = cv2.imread(tree, cv2.IMREAD_GRAYSCALE)
thresh = cv2.threshold(image,0,255,cv2.THRESH_OTSU + cv2.THRESH_BINARY)[1]
pixels = cv2.countNonZero(thresh)
# pixels = len(np.column_stack(np.where(thresh > 0)))

image_area = image.shape[0] * image.shape[1]
area_ratio = (pixels / image_area) * 100

print('pixels', pixels)
print('area ratio', area_ratio)
# Out:
# pixels 1244
# area ratio 0.6911111111111111

# %%
image = cv2.imread(barenland, cv2.IMREAD_GRAYSCALE)
thresh = cv2.threshold(image,0,255,cv2.THRESH_OTSU + cv2.THRESH_BINARY)[1]
pixels = cv2.countNonZero(thresh)
# pixels = len(np.column_stack(np.where(thresh > 0)))

image_area = image.shape[0] * image.shape[1]
area_ratio = (pixels / image_area) * 100

print('pixels', pixels)
print('area ratio', area_ratio)
# Out:
# pixels 8463
# area ratio 4.701666666666666

# %%
image = cv2.imread(cultivated_land, cv2.IMREAD_GRAYSCALE)
thresh = cv2.threshold(image,0,255,cv2.THRESH_OTSU + cv2.THRESH_BINARY)[1]
pixels = cv2.countNonZero(thresh)
# pixels = len(np.column_stack(np.where(thresh > 0)))

image_area = image.shape[0] * image.shape[1]
area_ratio = (pixels / image_area) * 100

print('pixels', pixels)
print('area ratio', area_ratio)
# Out:
# pixels 103133
# area ratio 57.29611111111112

# %%
image = cv2.imread(crop, cv2.IMREAD_GRAYSCALE)
thresh = cv2.threshold(image,0,255,cv2.THRESH_OTSU + cv2.THRESH_BINARY)[1]
pixels = cv2.countNonZero(thresh)
# pixels = len(np.column_stack(np.where(thresh > 0)))

image_area = image.shape[0] * image.shape[1]
area_ratio = (pixels / image_area) * 100

print('pixels', pixels)
print('area ratio', area_ratio)
# Out:
# pixels 37578
# area ratio 20.876666666666665

# %%
tree=cv2.imread(tree)
plt.imshow(tree)
plt.show()

# %%
barenland=cv2.imread(barenland)
plt.imshow(barenland)
plt.show()

# %%
cultivated_land=cv2.imread(cultivated_land)
plt.imshow(cultivated_land)
plt.show()

# %%
crop=cv2.imread(crop)
plt.imshow(crop)
plt.show()
